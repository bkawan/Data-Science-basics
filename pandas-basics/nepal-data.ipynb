# %% [markdown]
# - @author bkawan
# - @date May 15 2016

# %%
import pandas as panda
from pandas import DataFrame, read_csv

# %%
location = 'nepal_data_csv/nepal.csv'

# %%
#df = panda.read_csv(location,skiprows=3,index_col='Indicator Name')
df = panda.read_csv(location,skiprows=3)

# %%
df=df[['Indicator Name','2010','2011','2012']]

df
# Out:
#                                          Indicator Name          2010  \
# 0                      Agricultural machinery, tractors           NaN
# 1     Fertilizer consumption (% of fertilizer produc...           NaN
# 2     Fertilizer consumption (kilograms per hectare ...  2.508670e+01
# 3                            Agricultural land (sq. km)  4.126000e+04
# 4                    Agricultural land (% of land area)  2.878270e+01
# 5                                Arable land (hectares)  2.180000e+06
# 6                     Arable land (hectares per person)  8.111353e-02
# 7                          Arable land (% of land area)  1.520753e+01
# 8               Land under cereal production (hectares)  3.393553e+06
# 9                   Permanent cropland (% of land area)  1.060342e+00
# 10    Rural land area where elevation is below 5 met...           NaN
# 11    Rural land area where elevation is below 5 met...           NaN
# ...

# %%
df =df.dropna()
df = df.set_index('Indicator Name').head()
# Out:
#                                                             2010  \
# Indicator Name
# Fertilizer consumption (kilograms per hectare o...  2.508670e+01
# Agricultural land (sq. km)                          4.126000e+04
# Agricultural land (% of land area)                  2.878270e+01
# Arable land (hectares)                              2.180000e+06
# Arable land (hectares per person)                   8.111353e-02
#
#                                                             2011          2012
# Indicator Name
# Fertilizer consumption (kilograms per hectare o...  3.488371e+01  4.406988e+01
# Agricultural land (sq. km)                          4.126600e+04  4.121000e+04
# Agricultural land (% of land area)                  2.878689e+01  2.874782e+01
# Arable land (hectares)                              2.162700e+06  2.118000e+06
# Arable land (hectares per person)                   7.957177e-02  7.701674e-02

# %%
df.transpose()
# Out:
#                                                              2     \
# Indicator Name  Fertilizer consumption (kilograms per hectare ...
# 2010                                                      25.0867
# 2011                                                      34.8837
# 2012                                                      44.0699
#
#                                       3     \
# Indicator Name  Agricultural land (sq. km)
# 2010                                 41260
# 2011                                 41266
# 2012                                 41210
#
#                                               4                       5     \
# Indicator Name  Agricultural land (% of land area)  Arable land (hectares)
# 2010                                       28.7827                2.18e+06
# 2011                                       28.7869              2.1627e+06
# 2012                                       28.7478               2.118e+06
#
# ...
