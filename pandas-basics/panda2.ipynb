# %%
import pandas as pd
from pandas import DataFrame,read_csv

# %%
names = ["Nepal","Butan", "india"]
codes = [977,11,222]

# %%
names
# Out:
# ['Nepal', 'Butan', 'india']

# %%
codes
# Out:
# [977, 11, 222]

# %%
list(zip(names,codes))
# Out:
# [('Nepal', 977), ('Butan', 11), ('india', 222)]

# %%
dataset = list(zip(["john","harry","mary"], [12,52,44]))

# %%
df = DataFrame(data=dataset)

# %%
df
# Out:
#        0   1
# 0   john  12
# 1  harry  52
# 2   mary  44

# %%
_df = pd.read_csv("nepal_data_csv/nepal.csv" ,skiprows=3)

# %%
_df
# Out:
#      Country Name Country Code  \
# 0           Nepal          NPL
# 1           Nepal          NPL
# 2           Nepal          NPL
# 3           Nepal          NPL
# 4           Nepal          NPL
# 5           Nepal          NPL
# 6           Nepal          NPL
# 7           Nepal          NPL
# 8           Nepal          NPL
# 9           Nepal          NPL
# 10          Nepal          NPL
# 11          Nepal          NPL
# 12          Nepal          NPL
# 13          Nepal          NPL
# 14          Nepal          NPL
# 15          Nepal          NPL
# 16          Nepal          NPL
# 17          Nepal          NPL
# 18          Nepal          NPL
# 19          Nepal          NPL
# 20          Nepal          NPL
# 21          Nepal          NPL
# 22          Nepal          NPL
# 23          Nepal          NPL
# 24          Nepal          NPL
# 25          Nepal          NPL
# 26          Nepal          NPL
# 27          Nepal          NPL
# 28          Nepal          NPL
# ...

# %%
_df.head()
# Out:
#   Country Name Country Code  \
# 0        Nepal          NPL
# 1        Nepal          NPL
# 2        Nepal          NPL
# 3        Nepal          NPL
# 4        Nepal          NPL
#
#                                       Indicator Name     Indicator Code  1960  \
# 0                   Agricultural machinery, tractors     AG.AGR.TRAC.NO   NaN
# 1  Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS   NaN
# 2  Fertilizer consumption (kilograms per hectare ...     AG.CON.FERT.ZS   NaN
# 3                         Agricultural land (sq. km)     AG.LND.AGRI.K2   NaN
# 4                 Agricultural land (% of land area)     AG.LND.AGRI.ZS   NaN
#
#            1961          1962          1963          1964          1965  \
# 0    180.000000    190.000000    200.000000    215.000000    225.000000
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# ...

# %%
_df.tail()
# Out:
#      Country Name Country Code  \
# 1414        Nepal          NPL
# 1415        Nepal          NPL
# 1416        Nepal          NPL
# 1417        Nepal          NPL
# 1418        Nepal          NPL
#
#                                          Indicator Name Indicator Code  1960  \
# 1414                    Mobile account (% age 15+) [w2]    WP15163_4.1   NaN
# 1415              Mobile account, male (% age 15+) [w2]    WP15163_4.2   NaN
# 1416            Mobile account, female (% age 15+) [w2]    WP15163_4.3   NaN
# 1417  Mobile account, income, poorest 40% (% ages 15...    WP15163_4.8   NaN
# 1418  Mobile account, income, richest 60% (% ages 15...    WP15163_4.9   NaN
#
#       1961  1962  1963  1964  1965     ...       2007  2008  2009  2010  2011  \
# 1414   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN   NaN   NaN
# 1415   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN   NaN   NaN
# ...

# %%
_df.loc[5]
# Out:
# Country Name                       Nepal
# Country Code                         NPL
# Indicator Name    Arable land (hectares)
# Indicator Code            AG.LND.ARBL.HA
# 1960                                 NaN
# 1961                           1.806e+06
# 1962                           1.806e+06
# 1963                           1.816e+06
# 1964                           1.806e+06
# 1965                           1.806e+06
# 1966                           1.806e+06
# 1967                           1.819e+06
# 1968                           1.819e+06
# 1969                           1.819e+06
# 1970                           1.953e+06
# 1971                           1.953e+06
# 1972                           2.055e+06
# 1973                           2.165e+06
# 1974                            2.18e+06
# 1975                           2.195e+06
# 1976                            2.21e+06
# 1977                           2.225e+06
# 1978                            2.24e+06
# ...

# %%
mean1 = _df["2014"].mean()

# %%
mean2 = _df["2013"].mean()

# %%
mean2
# Out:
# 33765290259.507114

# %%
_df["2001"].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
_df["2001"].median()
# Out:
# 61.93
